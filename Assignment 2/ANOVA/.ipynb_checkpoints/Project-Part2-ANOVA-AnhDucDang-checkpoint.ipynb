# %% [markdown]
# # First Name: Anh Duc
# # Last Name: Dang

# %% [markdown]
# # Import Libraries

# %%
# import pandas as pd
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.stats.multicomp as multi 
# import library for visualizing data 
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Data

# %%
#read in csv file into 
dengue = pd.read_csv('Dengue.csv', low_memory=False) #increase efficiency

# avoid run time errors - bug fix for display formats
pd.set_option('display.float_format', lambda x:'%f'%x)

# %% [markdown]
# # Data management

# %%
#convert number of cases to numeric
dengue['total_cases'] = pd.to_numeric(dengue['total_cases'], errors='coerce')

#set the blank data to nan
dengue['total_cases'].fillna(np.nan)

#set the data type as categorical data
dengue['city'] = dengue['city'].astype('category')

#recoding for setting the full name of city
recode1 = {'sj':'San Juan', 'iq': 'Iquitos'} 
dengue['city'] = dengue['city'].map(recode1)

# %%
sub2=dengue.copy()

# %% [markdown]
# # Box Plot

# %%
# %matplotlib notebook
sns.boxplot(x='city', y='total_cases', data=dengue)
plt.xlabel('City')
plt.ylabel('Number of Dengue Cases')
plt.title('Distribution of Number of Dengue Cases in San Juan City and Iquitos City')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'Distribution of Number of Dengue Cases in San Juan City and Iquitos City')

# %% [markdown]
# # ANOVA

# %%
sub4 = sub2[['total_cases', 'city']].dropna()

# %%
#OLS Regression
model2 = smf.ols(formula='total_cases ~ C(city)', data=sub4).fit()
print (model2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            total_cases   R-squared:                       0.077
# Model:                            OLS   Adj. R-squared:                  0.076
# Method:                 Least Squares   F-statistic:                     115.0
# Date:                Fri, 25 May 2018   Prob (F-statistic):           8.08e-26
# Time:                        16:55:15   Log-Likelihood:                -7127.2
# No. Observations:                1377   AIC:                         1.426e+04
# Df Residuals:                    1375   BIC:                         1.427e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               7.6629      2.038      3.760      0.000       3.665      11.661
# C(city)[T.San Juan]    26.5221      2.473     10.723      0.000      21.670      31.374
# ==============================================================================
# Omnibus:                     1464.919   Durbin-Watson:                   0.080
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            83824.573
# Skew:                           5.267   Prob(JB):                         0.00
# Kurtosis:                      39.743   Cond. No.                         3.29
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print ('means for total_cases by city')
m2= sub4.groupby('city').mean()
print (m2)
# Out:
# means for total_cases by city
#           total_cases
# city
# Iquitos      7.662896
# San Juan    34.185027

# %%
print ('standard deviations for total_cases by city')
sd2 = sub4.groupby('city').std()
print (sd2)
# Out:
# standard deviations for total_cases by city
#           total_cases
# city
# Iquitos     11.295332
# San Juan    51.408689
